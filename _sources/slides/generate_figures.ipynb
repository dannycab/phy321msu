# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

plt.style.use('seaborn-v0_8-colorblind')

CQFOLDER = '../images/notes/'

# %% [markdown]
# # Clicker Question 6-3
#
# For the system of Linear Drag in 1D, we found a solution for the velocity as a function of time, with $v = 0$ at $t = 0$.
# $$v(t) = v_{term}\left(1-e^{-\dfrac{Ct}{m}}\right)$$
#
# where $v_{term} = \sqrt{\frac{mg}{C}}$.
#
# Which sketch is correct for the velocity of the ball?
# $$v(t) = v_{term}\left(1-e^{-\dfrac{Ct}{m}}\right)$$

# %%
# Clicker Question 6-3
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

plt.style.use('seaborn-v0_8-colorblind')

# Define constants
CQFOLDER = '../images/notes/'
WEEK = 'week3/'
TITLE = 'cq6-3'

# Define time array and constants
t = np.linspace(0, 10, 30)
m = 68.1
g = 9.8
c = 12.5

# Define the correct terminal velocity function
def terminal_velocity(m, g, c, t):
    return (m * g / c) * (1 - np.exp(-c * t / m))

# Define incorrect terminal velocity functions
def terminal_velocity1(m, g, c, t):
    return -m * g / c * (1 - np.exp(c * t / m))

def terminal_velocity2(m, g, c, t):
    return -1 / (m * g / c * (-c * t / m))

def terminal_velocity3(m, g, c, t):
    return -m * g / c * ((-c * t / m) ** 2)

# Calculate velocities
v = terminal_velocity(m, g, c, t)
v1 = terminal_velocity1(m, g, c, t)
v2 = terminal_velocity2(m, g, c, t)
v3 = terminal_velocity3(m, g, c, t)

# Plot all four functions in subplots
fig, axs = plt.subplots(2, 2, figsize=(8, 6))

# Plot incorrect function A
axs[0, 0].plot(t, v1, 'C0o-', label='A')
axs[0, 0].set_title(r'$v(t) = v_{term}\left(1-e^{-\dfrac{Ct}{m}}\right)$')
axs[0, 0].legend()
axs[0, 0].set_xticks([])
axs[0, 0].set_yticks([])
axs[0, 0].set_ylabel('v')

# Plot correct function B
axs[0, 1].plot(t, v, 'C1o-', label='B')
axs[0, 1].legend()
axs[0, 1].set_xticks([])
axs[0, 1].set_yticks([])

# Plot incorrect function C
axs[1, 0].plot(t, v2, 'C2o-', label='C')
axs[1, 0].legend()
axs[1, 0].set_xticks([])
axs[1, 0].set_yticks([])
axs[1, 0].set_xlabel('t')
axs[1, 0].set_ylabel('v')

# Plot incorrect function D
axs[1, 1].plot(t, v3, 'C3o-', label='D')
axs[1, 1].legend()
axs[1, 1].set_xticks([])
axs[1, 1].set_yticks([])
axs[1, 1].set_xlabel('t')

# Adjust layout and save the figure
plt.tight_layout()
plt.savefig(CQFOLDER + WEEK + TITLE + '.png')
plt.show()
# Out:
# /var/folders/5_/9z7lhk0s2y95hvkzs6lzdvvc0000gn/T/ipykernel_45150/3490806856.py:28: RuntimeWarning: divide by zero encountered in divide
#   return -1 / (m * g / c * (-c * t / m))

# %% [markdown]
# # Clicker Question 15-5

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

plt.style.use('seaborn-v0_8-colorblind')

# Define constants
CQFOLDER = '../images/notes/'
WEEK = 'week6/'
TITLE = 'cq15-5'

def Potential(x):
    return V0/(d**4)*(x**4 - 2*x**2*d**2 + d**4)

xlim = 1.5
steps = 1000
V0 = 1.0
d = 1.0

x = np.linspace(-xlim, xlim, steps)
V = Potential(x)

fig = plt.figure(figsize=(8, 6))
plt.plot(x, V,lw=2, label=r'$V(x)$')

plt.plot(0,Potential(0),'C1o', label='Unstable')
plt.plot(-d,Potential(-d),'C2o', label='Stable')
plt.plot(d,Potential(d),'C2o')

plt.xlabel('x (m)')
plt.ylabel('V (J)')
plt.legend()
plt.grid(True)

# Adjust layout and save the figure
plt.tight_layout()
plt.savefig(CQFOLDER + WEEK + TITLE + '.png')
plt.show()
